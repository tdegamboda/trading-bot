# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
ts = TimeSeries(key='8M5EP1KYXZZZL80P', output_format='pandas')

# %%
stock='AAPL'
data, meta_data = ts.get_daily(symbol=stock, outputsize='full')

# %%
print(data.head(10))
# Out:
#             1. open  2. high    3. low  4. close   5. volume
# date
# 2021-02-17   131.25  132.220  129.4700    130.84  97372199.0
# 2021-02-16   135.49  136.010  132.7900    133.19  80576316.0
# 2021-02-12   134.35  135.530  133.6921    135.37  60145130.0
# 2021-02-11   135.90  136.390  133.7700    135.13  64280029.0
# 2021-02-10   136.48  136.990  134.4000    135.39  72647988.0
# 2021-02-09   136.62  137.877  135.8500    136.01  75986989.0
# 2021-02-08   136.03  136.960  134.9200    136.91  71297214.0
# 2021-02-05   137.35  137.420  135.8600    136.76  75693830.0
# 2021-02-04   136.30  137.400  134.5900    137.39  84183061.0
# 2021-02-03   135.76  135.770  133.6100    133.94  89880937.0

# %%
data['4. close'].plot()
plt.title('Plots for ' + stock)
plt.show()

# %%
df = data['4. close']
average = df.rolling().mean()

# %%
df.plot()
average.plot()
plt.show()
